# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
train_data=pd.read_csv('train.csv')
test_data=pd.read_csv('test.csv')

# %%
train_data.iloc[:,1].replace("[^a-zA-Z]"," ",regex=True, inplace=True)
train_data["Review"]=train_data["Review"].str.lower()

# %%
test_data.iloc[:,1].replace("[^a-zA-Z]"," ",regex=True, inplace=True)
test_data["Review"]=test_data["Review"].str.lower()

# %%
COMMENT = 'Review'
train_data[COMMENT].fillna("unknown", inplace=True)
test_data[COMMENT].fillna("unknown", inplace=True)

# %%
train_data
# Out:
#         Id                                             Review  Components  \
# 0        0  for some reason everybody complains and i m co...           0
# 1        1  i like everything about it  great choice of sp...           0
# 2        2  excellent ceiling fan brace  easy to install a...           0
# 3        3  work great easy to use   no issues at all with...           0
# 4        4  i would recommend this product because it is p...           0
# ...    ...                                                ...         ...
# 6131  6131  easy to install  just be careful with the razo...           0
# 6132  6132  got a big pup and she had to learn about scree...           0
# 6133  6133  we installed our nest cam system a little over...           0
# 6134  6134  this is a below average camera   the only thin...           0
# 6135  6135                    so easy to install amd operate            0
#
#       Delivery and Customer Support  Design and Aesthetics  Dimensions  \
# ...

# %%
train_data.iloc[1,1]
# Out:
# 'i like everything about it  great choice of spray patterns  it puts out a large volume of water out of my    pipes'

# %%
headlines = []
for row in range(0,len(train_data.index)):
    headlines.append(train_data.iloc[row,1])

# %%
headlines[0]
# Out:
# 'for some reason everybody complains and i m complaining now about my toilet that i just boughtfor some reason it s not ceiling from the tank to the pedestal i can t get it sealed without cracking the toilet support design for some reason i m very unhappy with his toilet never buy american standard again'

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier

# %%
## implement BAG OF WORDS
countvector=CountVectorizer(ngram_range=(1,1))
traindataset=countvector.fit_transform(headlines)

# %%
# implement RandomForest Classifier
randomclassifier=RandomForestClassifier(n_estimators=200,criterion='entropy')
randomclassifier.fit(traindataset,train_data['Polarity'])
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=200)

# %%
headlines_test = []
for row in range(0,len(test_data.index)):
    headlines_test.append(test_data.iloc[row,1])

# %%
headlines_test[0]
# Out:
# 'made of very thin cheap metal broke on very first crimp had to rush to local hardware store spend    more on another because water was shut off in my home did not return because using case for the new one '

# %%
test_dataset = countvector.transform(headlines_test)

# %%
predictions = randomclassifier.predict(test_dataset)

# %%
## Import library to check accuracy
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
test_data['Polarity']=pd.DataFrame(predictions)

# %%
test_data.head(44)
# Out:
#     Id                                             Review  Components  \
# 0    0  made of very thin cheap metal broke on very fi...         NaN
# 1    1  as good as the brand names  no jams or misfire...         NaN
# 2    2  unit was easy to use  with understandable in s...         NaN
# 3    3  i am the new family plumber  works well  no pr...         NaN
# 4    4                       seems to be holding up well          NaN
# 5    5  bought this last week to fix my screen door   ...         NaN
# 6    6  honestly  i snagged   sets when i saw them at ...         NaN
# 7    7  good product and quality i used for framing an...         NaN
# 8    8  we really love our new project source toilet  ...         NaN
# 9    9  it s good  does have a little play in the cutt...         NaN
# 10  10  this product was very easy to install  worked ...         NaN
# 11  11                   easy to install and great price          NaN
# ...

# %%
Y=train_data.iloc[:,2:]

# %%
randomclassifier=RandomForestClassifier(n_estimators=200,criterion='entropy')
#randomclassifier.fit(traindataset,train_data['Polarity'])
for i in range (0,len(Y.columns)):
    randomclassifier.fit(traindataset,Y.iloc[:,i])
    y_pred=randomclassifier.predict(test_dataset)
    #acc=accuracy_score(Y.iloc[:,i],y_pred)
    #conf=confusion_matrix(Y.iloc[:,i],y_pred)
    test_data[test_data.columns[2+i]+'_pred']=pd.DataFrame(y_pred)

# %%
test_data.head(650)
# Out:
#       Id                                             Review  Components  \
# 0      0  made of very thin cheap metal broke on very fi...         NaN
# 1      1  as good as the brand names  no jams or misfire...         NaN
# 2      2  unit was easy to use  with understandable in s...         NaN
# 3      3  i am the new family plumber  works well  no pr...         NaN
# 4      4                       seems to be holding up well          NaN
# ..   ...                                                ...         ...
# 645  645         easy to load and use  grabs material well          NaN
# 646  646  i received this sprinkler but did not receive ...         NaN
# 647  647  despite both the website and the internal comp...         NaN
# 648  648  these nails where just what we needed but arri...         NaN
# 649  649  absolutely delighted with fit  material and co...         NaN
#
#      Delivery and Customer Support  Design and Aesthetics  Dimensions  \
# ...

# %%
test_data.drop(['Components', 'Delivery and Customer Support',
       'Design and Aesthetics', 'Dimensions', 'Features', 'Functionality',
       'Installation', 'Material', 'Price', 'Quality', 'Usability', 'Polarity'],axis=1,inplace=True)

# %%
test_data.to_csv('my_submission_file.csv', index=False)

# %%
from sklearn.preprocessing import LabelEncoder
lc=LabelEncoder()
test_data['Review']=lc.fit_transform(test_data['Review'])

# %%
test_data
# Out:
#         Id  Review  Components_pred  Delivery and Customer Support_pred  \
# 0        0    1304                0                                   0
# 1        1      62                0                                   0
# 2        2    2228                0                                   0
# 3        3     732                0                                   0
# 4        4    1602                0                                   0
# ...    ...     ...              ...                                 ...
# 2626  2626    2332                0                                   0
# 2627  2627     652                0                                   0
# 2628  2628    1396                0                                   0
# 2629  2629     164                0                                   0
# 2630  2630     368                0                                   0
#
#       Design and Aesthetics_pred  Dimensions_pred  Features_pred  \
# ...

# %%
test_data.to_csv('my_submission_file.csv', index=False)

# %%
from sklearn.metrics import log_loss
log_loss(test_data['Polarity_pred'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-513c3449a347> in <module>
#       1 from sklearn.metrics import log_loss
# ----> 2 log_loss(test_data['Polarity_pred'])
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# TypeError: log_loss() missing 1 required positional argument: 'y_pred'

# %%
test_data['Components_pred']
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2626    1
# 2627    1
# 2628    1
# 2629    1
# 2630    1
# Name: Polarity_pred, Length: 2631, dtype: int64

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(test_data['Components_pred'],test_data['Polarity_pred'])
# Out:
# array([[ 237, 2394],
#        [   0,    0]], dtype=int64)
